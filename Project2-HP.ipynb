# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
hp=pd.read_excel(r"C:\Users\ADMIN\Desktop\simplilearn-python\Projects\Housing Price.xlsx")
hp
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
hp.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
hp.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
hp[hp.total_bedrooms.isnull()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                  47         1256             NaN
# 341      -122.17     37.75                  38          992             NaN
# 538      -122.28     37.78                  29         5154             NaN
# 563      -122.24     37.75                  45          891             NaN
# 696      -122.10     37.69                  41          746             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                  18         3620             NaN
# 20268    -119.18     34.19                  19         2393             NaN
# 20372    -118.88     34.17                  15         4260             NaN
# 20460    -118.75     34.29                  17         5512             NaN
# 20484    -118.72     34.28                  17         3051             NaN
#
# ...

# %%
# Handling MIssing Values
mean_of_total_bedrooms=round(hp.total_bedrooms.mean())

# %%
hp=hp.fillna(value=mean_of_total_bedrooms)

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
hp.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %%
hp['ocean_proximity']
# Out:
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# 4        NEAR BAY
#            ...
# 20635      INLAND
# 20636      INLAND
# 20637      INLAND
# 20638      INLAND
# 20639      INLAND
# Name: ocean_proximity, Length: 20640, dtype: object

# %%
hp.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
# One hot encoding
hp=pd.get_dummies(data=hp,columns=['ocean_proximity'],drop_first=True)

# %% [markdown]
# All null values are cleared and all the object data-types are converted into numerical

# %%
hp
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
hp.rename(columns={'ocean_proximity_NEAR BAY':'ocean_proximity_NEAR_BAY','ocean_proximity_NEAR OCEAN':'ocean_proximity_NEAR_OCEAN','ocean_proximity_<1H OCEAN':'ocean_proximity_lessthan_1H_OCEAN'},inplace=True)

# %%
hp_x=hp.drop(labels='median_house_value',axis=1)
hp_x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
hp_y=hp["median_house_value"]
hp_y
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20640, dtype: int64

# %%
# Standardizing Data
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()

# %%
# Train Test Spit
from sklearn.model_selection import train_test_split
hp_x_train , hp_x_test  , hp_y_train , hp_y_test = train_test_split(hp_x , hp_y , test_size = .3)

# %%
hp_x_train=scalar.fit_transform(hp_x_train)

# %%
hp_x_test =scalar.transform(hp_x_test)

# %%
# Model Building using Linear regression
from sklearn.linear_model import LinearRegression
le=LinearRegression()

# %%
le.fit(hp_x_train,hp_y_train)
# Out:
# LinearRegression()

# %%
le.score(hp_x_train,hp_y_train)
# Out:
# 0.6443199268288049

# %%
le.score(hp_x_test,hp_y_test)
# Out:
# 0.647801709818807

# %%
hp_y_pred=le.predict(hp_x_test)

# %%
hp_y_pred
# Out:
# array([336303.10619997, 224846.36407026, 255293.96213937, ...,
#        168697.40599181,  23943.40218226, 205003.60592104])

# %%
hp_y_test
# Out:
# 10800    439100
# 9494     140500
# 8075     207500
# 1828     195800
# 717      170300
#           ...
# 18016    255100
# 15530    161100
# 29       132000
# 18694     81300
# 6276     153800
# Name: median_house_value, Length: 6192, dtype: int64

# %%
df={"actual":hp_y_test,"predicted":hp_y_pred}
compare=pd.DataFrame(df)

# %%
compare
# Out:
#        actual      predicted
# 10800  439100  336303.106200
# 9494   140500  224846.364070
# 8075   207500  255293.962139
# 1828   195800  186370.151999
# 717    170300  212865.097276
# ...       ...            ...
# 18016  255100  269954.096509
# 15530  161100  179078.057553
# 29     132000  168697.405992
# 18694   81300   23943.402182
# 6276   153800  205003.605921
#
# [6192 rows x 2 columns]

# %%
compare.predicted =[round(i) for i in compare.predicted]

# %%
compare
# Out:
#        actual  predicted
# 10800  439100     336303
# 9494   140500     224846
# 8075   207500     255294
# 1828   195800     186370
# 717    170300     212865
# ...       ...        ...
# 18016  255100     269954
# 15530  161100     179078
# 29     132000     168697
# 18694   81300      23943
# 6276   153800     205004
#
# [6192 rows x 2 columns]

# %%
# Checking wither the error terms are normally distributed with a mean of zero
compare["errors"]=compare.actual-compare.predicted
compare
# Out:
#        actual  predicted  errors
# 10800  439100     336303  102797
# 9494   140500     224846  -84346
# 8075   207500     255294  -47794
# 1828   195800     186370    9430
# 717    170300     212865  -42565
# ...       ...        ...     ...
# 18016  255100     269954  -14854
# 15530  161100     179078  -17978
# 29     132000     168697  -36697
# 18694   81300      23943   57357
# 6276   153800     205004  -51204
#
# [6192 rows x 3 columns]

# %%
plt.figure(figsize=(8, 5))
plt.hist(compare["errors"],bins=100)
plt.title("Error Distribution");

# %%
plt.figure(figsize=(8, 4), dpi=120, edgecolor='b')
x=[i for i in range(6192)]
y=[0 for i in x]
plt.scatter( x, compare.errors, label = 'Errors')
plt.plot(x,y,color='r',label='Mean')
plt.title("Error Variation about the Mean")
plt.legend(loc='lower left');

# %% [markdown]
# The errors are normally distributed

# %%
from sklearn import metrics
mse=metrics.mean_squared_error(hp_y_test,hp_y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 68119.94808011748

# %%
# Model building using Ridge and Lasso regression
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(hp_x_train , hp_y_train)
ridge.score(hp_x_test , hp_y_test)
hp_y_pred=ridge.predict(hp_x_test)
mse=metrics.mean_squared_error(hp_y_test,hp_y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 68120.90370964997

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(hp_x_train , hp_y_train)
hp_y_pred=lasso.predict(hp_x_test)
mse=metrics.mean_squared_error(hp_y_test,hp_y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 68120.36603466402

# %%
# Model building using RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(hp_x_train, hp_y_train)
hp_y_pred=rf.predict(hp_x_test)
mse=metrics.mean_squared_error(hp_y_test,hp_y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 48155.80052598723

# %%
# Model building using neural network
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Activation, Dense

# %%
model = Sequential()
model.add(Dense(12, input_dim=12, kernel_initializer='normal', activation='relu'))
model.add(Dense(12, kernel_initializer='normal', activation='relu'))
model.add(Dense(24, kernel_initializer='normal', activation='relu'))
model.add(Dense(48, kernel_initializer='normal', activation='relu'))
model.add(Dense(48, kernel_initializer='normal', activation='relu'))
model.add(Dense(48, kernel_initializer='normal', activation='relu'))
model.add(Dense(48, kernel_initializer='normal', activation='relu'))
model.add(Dense(48, kernel_initializer='normal', activation='relu'))
model.add(Dense(20, kernel_initializer='normal', activation='relu'))
model.add(Dense(20, kernel_initializer='normal', activation='relu'))
model.add(Dense(20, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal', activation='relu'))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(hp_x_train , hp_y_train, batch_size=10, epochs=20, validation_split = 0.3)
# Out:
# Epoch 1/20
# 1012/1012 [==============================] - 3s 3ms/step - loss: 12728481792.0000 - val_loss: 4808677888.0000
# Epoch 2/20
# 1012/1012 [==============================] - 3s 3ms/step - loss: 4885402624.0000 - val_loss: 4410085376.0000
# Epoch 3/20
# 1012/1012 [==============================] - 3s 3ms/step - loss: 4675825152.0000 - val_loss: 4331749888.0000
# Epoch 4/20
# 1012/1012 [==============================] - 3s 3ms/step - loss: 4573811712.0000 - val_loss: 4234300928.0000
# Epoch 5/20
# 1012/1012 [==============================] - 3s 3ms/step - loss: 4558637568.0000 - val_loss: 4520955392.0000
# Epoch 6/20
# 1012/1012 [==============================] - 3s 3ms/step - loss: 4471007744.0000 - val_loss: 4180450816.0000
# Epoch 7/20
# 1012/1012 [==============================] - 3s 3ms/step - loss: 4483045376.0000 - val_loss: 4498330624.0000
# Epoch 8/20
# 1012/1012 [==============================] - 3s 3ms/step - loss: 4450186752.0000 - val_loss: 4329604096.0000
# ...

# %%
hp_y_pred=model.predict(hp_x_test, batch_size=20)
mse=metrics.mean_squared_error(hp_y_test,hp_y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 64120.13828964095
